# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitad001/Data-Science-course/blob/main/Pyhtonbasic_ipyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("arpita")
# Out:
# arpita
